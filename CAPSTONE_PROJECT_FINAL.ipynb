# %% [markdown]
# ## CAPSTONE PROJECT FOR FINDING OPTIMIZED VENUE AT FRANCE

# %% [markdown]
# # Introduction

# %% [markdown]
# This report is for the final course of the Data Science Specialization. A 9-courses series created by IBM, hosted on Coursera platform. The problem and the analysis approach are left for the learner to decide, with a requirement of leveraging the Foursquare location data to explore or compare neighborhoods or cities of your choice or to come up with a problem that you can use the Foursquare location data to solve.
#
# In this project, the problem is to find the optimal location or finding the cityof cluster which has user preferred venue eg. BAR,PLAZA and GYM in France. To achieve this task, an analytical approach will be used, based on advance machine learning techniques and data analysis,concretely clustering and perhaps some data visualization techniques.
#
# So can the city surrounding has user preferred venues ?
# If so, what types of venues cluster has the most affect, both positively and negatively?
#
# The Target Audience for this project is for who prefer to stay in hotel based on
# on their preferred venues(eg.Tourists).

# %% [markdown]
# # Import required libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.18.1               |             py_0          51 KB  conda-forge
#     openssl-1.0.2p             |       h470a237_2         3.1 MB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.2 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0         conda-forge
#     geopy:         1.18.1-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     openssl:       1.0.2p-h470a237_1 conda-forge --> 1.0.2p-h470a237_2 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.18.1         | 51 KB     | ##################################### | 100%
# openssl-1.0.2p       | 3.1 MB    | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-2.3.0               |        py36_1001         533 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         631 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.3.0-py36_1001 conda-forge
#     branca:  0.3.1-py_0      conda-forge
#     folium:  0.5.0-py_0      conda-forge
#     vincent: 0.4.4-py_1      conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-2.3.0         | 533 KB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# # Download and Explore Dataset

# %% [markdown]
# Get Data from https://simplemaps.com/data/fr-cities as CSV

# %%
df = pd.read_csv('france_geo.csv', sep = ';')

# %%
data_df = pd.DataFrame(df)

# %%
data_df.head()
# Out:
#         city        lat       lng country iso2  capital  population
# 0      Paris  48.866667  2.333333  France   FR  primary     9904000
# 1       Lyon  45.748457  4.846711  France   FR    admin     1423000
# 2  Marseille  43.285413  5.376060  France   FR    admin     1400000
# 3      Lille  50.632971  3.058585  France   FR    admin     1044000
# 4       Nice  43.713644  7.259520  France   FR   927000      338620

# %% [markdown]
# Change the Column names as understandable

# %%
data_df.columns = ['CITY', 'LATITUDE', 'LONGITUDE','COUNTRY','COUNTRY_CODE','CAPITAL','POPULATION']

# %% [markdown]
# Drop the columns that are not required

# %%
data_df = data_df.drop(['COUNTRY_CODE','CAPITAL'], axis=1)

# %%
data_df.head()
# Out:
#         CITY   LATITUDE  LONGITUDE COUNTRY  POPULATION
# 0      Paris  48.866667   2.333333  France     9904000
# 1       Lyon  45.748457   4.846711  France     1423000
# 2  Marseille  43.285413   5.376060  France     1400000
# 3      Lille  50.632971   3.058585  France     1044000
# 4       Nice  43.713644   7.259520  France      338620

# %% [markdown]
# ### Use geopy library to get the latitude and longitude values of France

# %%
address = 'France'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of france are {}, {}.'.format(latitude, longitude))
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   This is separate from the ipykernel package so we can avoid doing imports until
# The geograpical coordinate of france are 46.603354, 1.8883335.

# %% [markdown]
# #### Create a map of France with cities superimposed on top.

# %%
# create map of france using latitude and longitude values
map_france = folium.Map(location=[latitude, longitude], zoom_start=6)

# add markers to map
for lat, lng, borough, neighborhood in zip(data_df['LATITUDE'], data_df['LONGITUDE'], data_df['COUNTRY'], data_df['CITY']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_france)  
    
map_france
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'ESYH340ZLYESMFLKUKCHDQ33YNUJINGWDUPRBZC21VVYTFMT' # your Foursquare ID
CLIENT_SECRET = 'EYRI0QRQTSMVWD5AWU1JGD4FXZBNCPOXM4NRO1TKBS3EVHOZ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ESYH340ZLYESMFLKUKCHDQ33YNUJINGWDUPRBZC21VVYTFMT
# CLIENT_SECRET:EYRI0QRQTSMVWD5AWU1JGD4FXZBNCPOXM4NRO1TKBS3EVHOZ

# %% [markdown]
# #### Let's explore the first neighborhood/City in our dataframe.

# %%
data_df.loc[0,'CITY']
# Out:
# 'Paris'

# %%
neighborhood_latitude = data_df.loc[0, 'LATITUDE'] # neighborhood latitude value
neighborhood_longitude = data_df.loc[0, 'LONGITUDE'] # neighborhood longitude value

neighborhood_name = data_df.loc[0, 'CITY'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Paris are 48.866667, 2.333333.

# %%
# type your answer here
LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 500 # define radius

#create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=ESYH340ZLYESMFLKUKCHDQ33YNUJINGWDUPRBZC21VVYTFMT&client_secret=EYRI0QRQTSMVWD5AWU1JGD4FXZBNCPOXM4NRO1TKBS3EVHOZ&v=20180605&ll=48.866667,2.333333&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c388426dd57975fd5e7d21f'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Place Vendôme',
#   'headerFullLocation': 'Place Vendôme, Paris',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 244,
#   'suggestedBounds': {'ne': {'lat': 48.8711670045, 'lng': 2.340161078526742},
#    'sw': {'lat': 48.8621669955, 'lng': 2.326504921473258}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cbdcb0b7148f04d510aefab',
#        'name': 'Pierre Hermé',
#        'location': {'address': "39 avenue de l'Opéra",
#         'lat': 48.86822151447183,
#         'lng': 2.333396617684349,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86822151447183,
#           'lng': 2.333396617684349}],
#         'distance': 173,
#         'postalCode': '75002',
#         'cc': 'FR',
#         'neighborhood': 'Opera',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ["39 avenue de l'Opéra", '75002 Paris', 'France']},
#        'categories': [{'id': '5744ccdfe4b0c0459246b4e2',
#          'name': 'Pastry Shop',
#          'pluralName': 'Pastry Shops',
#          'shortName': 'Pastry',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cbdcb0b7148f04d510aefab-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55e9eee8498e43ed2bd190f8',
#        'name': 'Le Roch Hotel & Spa Paris',
#        'location': {'address': '28 rue Saint Roch',
#         'lat': 48.86620012005232,
#         'lng': 2.3329946840505174,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86620012005232,
#           'lng': 2.3329946840505174}],
#         'distance': 57,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['28 rue Saint Roch', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55e9eee8498e43ed2bd190f8-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f7c9505e4b0b7ee688be2db',
#        'name': 'Cantine California',
#        'location': {'address': 'Marché Saint-Honoré',
#         'lat': 48.86740061772486,
#         'lng': 2.3320168163937907,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86740061772486,
#           'lng': 2.3320168163937907}],
#         'distance': 126,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['Marché Saint-Honoré', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'shortName': 'Food Truck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '80488502'}},
#       'referralId': 'e-0-4f7c9505e4b0b7ee688be2db-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c360bbd93db0f4705641d92',
#        'name': 'Boulangerie Aki',
#        'location': {'address': '16 rue Sainte-Anne',
#         'lat': 48.86621097624905,
#         'lng': 2.335457623784485,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86621097624905,
#           'lng': 2.335457623784485}],
#         'distance': 163,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['16 rue Sainte-Anne', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c360bbd93db0f4705641d92-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57a62d2f498ea38dc4db9391',
#        'name': 'Brasserie Réjane',
#        'location': {'address': "16 avenue de l'Opéra",
#         'lat': 48.865485991272,
#         'lng': 2.3348240554332733,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.865485991272,
#           'lng': 2.3348240554332733}],
#         'distance': 170,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ["16 avenue de l'Opéra", '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57a62d2f498ea38dc4db9391-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6c1849f964a52094232ce3',
#        'name': 'JanTchi',
#        'location': {'address': '6 rue Thérèse',
#         'lat': 48.86600128752999,
#         'lng': 2.335976674778051,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86600128752999,
#           'lng': 2.335976674778051}],
#         'distance': 207,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['6 rue Thérèse', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6c1849f964a52094232ce3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '579fbf15498e7f9f1b92154f',
#        'name': 'Nolinski',
#        'location': {'address': "16 avenue de l'Opéra",
#         'lat': 48.8653672585173,
#         'lng': 2.334584093466682,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.8653672585173,
#           'lng': 2.334584093466682}],
#         'distance': 171,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ["16 avenue de l'Opéra", '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-579fbf15498e7f9f1b92154f-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '555e18a5498e26f7534a977c',
#        'name': 'Hakata Choten',
#        'location': {'address': '53 rue des Petits Champs',
#         'lat': 48.867125,
#         'lng': 2.334818,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.867125,
#           'lng': 2.334818}],
#         'distance': 120,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['53 rue des Petits Champs',
#          '75001 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-555e18a5498e26f7534a977c-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f0b706de5e8207020057ed7',
#        'name': 'Sanukiya',
#        'location': {'address': "9 rue d'Argenteuil",
#         'lat': 48.86471255164696,
#         'lng': 2.334059025405792,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86471255164696,
#           'lng': 2.334059025405792}],
#         'distance': 223,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ["9 rue d'Argenteuil", '75001 Paris', 'France']},
#        'categories': [{'id': '55a59bace4b013909087cb2a',
#          'name': 'Udon Restaurant',
#          'pluralName': 'Udon Restaurants',
#          'shortName': 'Udon',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f0b706de5e8207020057ed7-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf18d63324cc9b62b2bcc92',
#        'name': 'Gambino',
#        'location': {'address': '6 rue Gomboust',
#         'lat': 48.867305021992415,
#         'lng': 2.3330856045899147,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.867305021992415,
#           'lng': 2.3330856045899147}],
#         'distance': 73,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['6 rue Gomboust', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf18d63324cc9b62b2bcc92-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fa81d41e4b0d6f4be98c6bd',
#        'name': 'Reebok CrossFit Louvre',
#        'location': {'address': "31 avenue de l'Opéra",
#         'lat': 48.86726626129496,
#         'lng': 2.3334686520958163,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86726626129496,
#           'lng': 2.3334686520958163}],
#         'distance': 67,
#         'postalCode': '75002',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ["31 avenue de l'Opéra", '75002 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fa81d41e4b0d6f4be98c6bd-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1c15a4f964a520d90124e3',
#        'name': 'Aki',
#        'location': {'address': '11 bis rue Sainte-Anne',
#         'lat': 48.86614727762348,
#         'lng': 2.3354142848003927,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86614727762348,
#           'lng': 2.3354142848003927}],
#         'distance': 163,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['11 bis rue Sainte-Anne',
#          '75001 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1c15a4f964a520d90124e3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb9e9687421a593e723c340',
#        'name': "Brentano's",
#        'location': {'address': "37 avenue de l'Opéra",
#         'lat': 48.868111613191154,
#         'lng': 2.3335079079517094,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.868111613191154,
#           'lng': 2.3335079079517094}],
#         'distance': 161,
#         'postalCode': '75002',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ["37 avenue de l'Opéra", '75002 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb9e9687421a593e723c340-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f58dfcfe4b0c3218c855f34',
#        'name': 'Balenciaga',
#        'location': {'address': '336, Rue Saint-Honoré',
#         'lat': 48.8659267043082,
#         'lng': 2.330284387731581,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.8659267043082,
#           'lng': 2.330284387731581}],
#         'distance': 237,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['336, Rue Saint-Honoré',
#          '75001 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d108951735',
#          'name': "Women's Store",
#          'pluralName': "Women's Stores",
#          'shortName': "Women's Store",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f58dfcfe4b0c3218c855f34-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda20f964a5209a3921e3',
#        'name': 'Michel Cluizel',
#        'location': {'address': '201 rue Saint-Honoré',
#         'lat': 48.86504641171176,
#         'lng': 2.331745211681605,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86504641171176,
#           'lng': 2.331745211681605}],
#         'distance': 214,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['201 rue Saint-Honoré', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d117951735',
#          'name': 'Candy Store',
#          'pluralName': 'Candy Stores',
#          'shortName': 'Candy Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda20f964a5209a3921e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b649f4af964a52006c32ae3',
#        'name': 'Juji-ya',
#        'location': {'address': '46 rue Sainte-Anne',
#         'lat': 48.86749292666208,
#         'lng': 2.3361173828149555,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86749292666208,
#           'lng': 2.3361173828149555}],
#         'distance': 223,
#         'postalCode': '75002',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['46 rue Sainte-Anne', '75002 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b649f4af964a52006c32ae3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3a1f92f964a5205a6125e3',
#        'name': 'K-mart',
#        'location': {'address': '6-8 rue Sainte-Anne',
#         'lat': 48.865371417068246,
#         'lng': 2.335009233295977,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.865371417068246,
#           'lng': 2.335009233295977}],
#         'distance': 189,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['6-8 rue Sainte-Anne', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b3a1f92f964a5205a6125e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda1cf964a520063921e3',
#        'name': 'La Pépinière Théâtre',
#        'location': {'address': '7 rue Louis Le Grand',
#         'lat': 48.868629398163556,
#         'lng': 2.332388342913275,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.868629398163556,
#           'lng': 2.332388342913275}],
#         'distance': 229,
#         'postalCode': '75002',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['7 rue Louis Le Grand', '75002 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda1cf964a520063921e3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b02f691f964a5207b4b22e3',
#        'name': 'Place du Marché Saint-Honoré',
#        'location': {'address': 'Place du Marché Saint-Honoré',
#         'lat': 48.86737955827214,
#         'lng': 2.3322155174163828,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86737955827214,
#           'lng': 2.3322155174163828}],
#         'distance': 113,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['Place du Marché Saint-Honoré',
#          '75001 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b02f691f964a5207b4b22e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be56f3cbcef2d7f6ec203e5',
#        'name': 'Naniwa-Ya',
#        'location': {'address': '11 rue Sainte-Anne',
#         'lat': 48.86602221123425,
#         'lng': 2.3352398397400975,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86602221123425,
#           'lng': 2.3352398397400975}],
#         'distance': 157,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['11 rue Sainte-Anne', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be56f3cbcef2d7f6ec203e5-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d09ffa65edd54814b50039b',
#        'name': 'Épices Roellinger',
#        'location': {'address': '51 rue Sainte-Anne',
#         'lat': 48.86746605756848,
#         'lng': 2.3360988733440986,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86746605756848,
#           'lng': 2.3360988733440986}],
#         'distance': 221,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['51 rue Sainte-Anne', '75001 Paris', 'France']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b2c',
#          'name': 'Herbs & Spices Store',
#          'pluralName': 'Herbs & Spices Stores',
#          'shortName': 'Herbs & Spices Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d09ffa65edd54814b50039b-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda00f964a520ed3021e3',
#        'name': 'Hôtel Edouard 7',
#        'location': {'address': "39 Avenue de l'Opéra",
#         'lat': 48.868357432638625,
#         'lng': 2.3330182044620926,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.868357432638625,
#           'lng': 2.3330182044620926}],
#         'distance': 189,
#         'postalCode': '75002',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ["39 Avenue de l'Opéra", '75002 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda00f964a520ed3021e3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5156d1eae4b0702abe4a37b4',
#        'name': 'Udon Jubey',
#        'location': {'address': '39 Rue Sainte Anne',
#         'lat': 48.866432,
#         'lng': 2.33557,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.866432,
#           'lng': 2.33557}],
#         'distance': 165,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['39 Rue Sainte Anne', '75001 Paris', 'France']},
#        'categories': [{'id': '55a59bace4b013909087cb2a',
#          'name': 'Udon Restaurant',
#          'pluralName': 'Udon Restaurants',
#          'shortName': 'Udon',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5156d1eae4b0702abe4a37b4-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd18adca8b3a59347d9655f',
#        'name': 'Ace Gourmet Bento',
#        'location': {'address': '18 rue Thérèse',
#         'lat': 48.8663599813833,
#         'lng': 2.3350434056519163,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.8663599813833,
#           'lng': 2.3350434056519163}],
#         'distance': 129,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['18 rue Thérèse', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd18adca8b3a59347d9655f-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5001951de4b04575fdb89702',
#        'name': 'ZenZoo – Bar à Thé',
#        'location': {'address': '2 rue Chabanais',
#         'lat': 48.867020860798846,
#         'lng': 2.336737853474915,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.867020860798846,
#           'lng': 2.336737853474915}],
#         'distance': 252,
#         'postalCode': '75002',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['2 rue Chabanais', '75002 Paris', 'France']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'shortName': 'Bubble Tea',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5001951de4b04575fdb89702-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '514208e8e4b080a1fe3c7935',
#        'name': 'Jin',
#        'location': {'address': '6 rue de la Sourdière',
#         'lat': 48.865348322565886,
#         'lng': 2.331786581284321,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.865348322565886,
#           'lng': 2.331786581284321}],
#         'distance': 185,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['6 rue de la Sourdière',
#          '75001 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-514208e8e4b080a1fe3c7935-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53c10d23498e6c9cbdc6296e',
#        'name': 'Kunitoraya',
#        'location': {'address': '1 rue Villedo',
#         'lat': 48.86597257654707,
#         'lng': 2.3368800972156336,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86597257654707,
#           'lng': 2.3368800972156336}],
#         'distance': 271,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'neighborhood': 'Palais-Royal',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['1 rue Villedo', '75001 Paris', 'France']},
#        'categories': [{'id': '55a59bace4b013909087cb2a',
#          'name': 'Udon Restaurant',
#          'pluralName': 'Udon Restaurants',
#          'shortName': 'Udon',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53c10d23498e6c9cbdc6296e-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b751aa0f964a5200cfe2de3',
#        'name': 'Ebis',
#        'location': {'address': '19 rue Saint-Roch',
#         'lat': 48.86537548985992,
#         'lng': 2.332309837176929,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86537548985992,
#           'lng': 2.332309837176929}],
#         'distance': 162,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['19 rue Saint-Roch', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b751aa0f964a5200cfe2de3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1bb46ff964a520c0fc23e3',
#        'name': 'Kioko',
#        'location': {'address': '46 rue des Petits Champs',
#         'lat': 48.867446074793556,
#         'lng': 2.3343399167060848,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.867446074793556,
#           'lng': 2.3343399167060848}],
#         'distance': 113,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['46 rue des Petits Champs',
#          '75001 Paris',
#          'France']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1bb46ff964a520c0fc23e3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b070d8af964a52053f622e3',
#        'name': 'Higuma',
#        'location': {'address': '32 bis rue Sainte-Anne',
#         'lat': 48.86654699573711,
#         'lng': 2.335818970910325,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86654699573711,
#           'lng': 2.335818970910325}],
#         'distance': 182,
#         'postalCode': '75002',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['32 bis rue Sainte-Anne',
#          '75002 Paris',
#          'France']},
#        'categories': [{'id': '55a59bace4b013909087cb24',
#          'name': 'Ramen Restaurant',
#          'pluralName': 'Ramen Restaurants',
#          'shortName': 'Ramen',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b070d8af964a52053f622e3-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54402a4e498eb9147ea93b02',
#        'name': 'Dosanko どさん子',
#        'location': {'address': '40 rue Sainte-Anne',
#         'lat': 48.86701213570369,
#         'lng': 2.3358702234568858,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86701213570369,
#           'lng': 2.3358702234568858}],
#         'distance': 189,
#         'postalCode': '75002',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['40 rue Sainte-Anne', '75002 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'shortName': 'Noodles',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54402a4e498eb9147ea93b02-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda09f964a5200e3421e3',
#        'name': 'Place Vendôme',
#        'location': {'address': 'Place Vendôme',
#         'lat': 48.86779769319868,
#         'lng': 2.3297411847276526,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86779769319868,
#           'lng': 2.3297411847276526}],
#         'distance': 291,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['Place Vendôme', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda09f964a5200e3421e3-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda21f964a520c23921e3',
#        'name': 'Van Cleef & Arpels',
#        'location': {'address': '20-22 place Vendôme',
#         'lat': 48.86750752678968,
#         'lng': 2.3307025821304705,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86750752678968,
#           'lng': 2.3307025821304705}],
#         'distance': 214,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['20-22 place Vendôme', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d111951735',
#          'name': 'Jewelry Store',
#          'pluralName': 'Jewelry Stores',
#          'shortName': 'Jewelry',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/jewelry_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda21f964a520c23921e3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5952e2f964a5200b8528e3',
#        'name': 'Takara',
#        'location': {'address': '14 rue Molière',
#         'lat': 48.86498580244075,
#         'lng': 2.3358285356490502,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86498580244075,
#           'lng': 2.3358285356490502}],
#         'distance': 261,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['14 rue Molière', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5952e2f964a5200b8528e3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e9d6adde5fa336fdb43cd62',
#        'name': 'Hôtel Le Pradey',
#        'location': {'address': '5 avenue Saint-Roch',
#         'lat': 48.86445923930909,
#         'lng': 2.33165399481692,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86445923930909,
#           'lng': 2.33165399481692}],
#         'distance': 274,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['5 avenue Saint-Roch', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e9d6adde5fa336fdb43cd62-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5511b895498e1e2d8edb73e8',
#        'name': 'Ellsworth',
#        'location': {'address': '34 rue de Richelieu',
#         'lat': 48.865527916411786,
#         'lng': 2.337056774451994,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.865527916411786,
#           'lng': 2.337056774451994}],
#         'distance': 300,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['34 rue de Richelieu', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5511b895498e1e2d8edb73e8-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda01f964a520fe3021e3',
#        'name': 'Hôtel Ascot Opéra',
#        'location': {'address': '2 rue Monsigny',
#         'lat': 48.86823195689058,
#         'lng': 2.3351535465850186,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86823195689058,
#           'lng': 2.3351535465850186}],
#         'distance': 219,
#         'postalCode': '75002',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['2 rue Monsigny', '75002 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '42945382'}},
#       'referralId': 'e-0-4adcda01f964a520fe3021e3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba4d1b9f964a520e1b738e3',
#        'name': 'Nodaiwa',
#        'location': {'address': '272 rue Saint-Honoré',
#         'lat': 48.86435425075339,
#         'lng': 2.3331572600591257,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86435425075339,
#           'lng': 2.3331572600591257}],
#         'distance': 257,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['272 rue Saint-Honoré', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba4d1b9f964a520e1b738e3-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b212aa4f964a520983724e3',
#        'name': 'Charvet',
#        'location': {'address': '28 place Vendôme',
#         'lat': 48.868312152527395,
#         'lng': 2.3302816660179584,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.868312152527395,
#           'lng': 2.3302816660179584}],
#         'distance': 288,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['28 place Vendôme', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d106951735',
#          'name': "Men's Store",
#          'pluralName': "Men's Stores",
#          'shortName': "Men's Store",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_men_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b212aa4f964a520983724e3-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54883c18498e71cde079f1b7',
#        'name': 'Nest',
#        'location': {'address': '9 rue Villedo',
#         'lat': 48.86636733003508,
#         'lng': 2.335944493658269,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86636733003508,
#           'lng': 2.335944493658269}],
#         'distance': 194,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['9 rue Villedo', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54883c18498e71cde079f1b7-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7920a2f964a52069ec2ee3',
#        'name': 'Kintaro',
#        'location': {'address': '24 rue Saint-Augustin',
#         'lat': 48.868972,
#         'lng': 2.334859,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.868972,
#           'lng': 2.334859}],
#         'distance': 279,
#         'postalCode': '75002',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['24 rue Saint-Augustin',
#          '75002 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7920a2f964a52069ec2ee3-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5603cf2e498e56742e72d924',
#        'name': 'Kosyuen 華修園',
#        'location': {'address': '258 Rue Saint Honoré',
#         'lat': 48.864163247442406,
#         'lng': 2.3335674783429994,
#         'labeledLatLngs': [{'label': 'display',
# ...
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda12f964a520523621e3',
#        'name': 'Juveniles',
#        'location': {'address': '47 rue de Richelieu',
#         'lat': 48.86621687123557,
#         'lng': 2.337148998297595,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86621687123557,
#           'lng': 2.337148998297595}],
#         'distance': 283,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['47 rue de Richelieu', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda12f964a520523621e3-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5953f0feeacf45405b8137bf',
#        'name': 'La Rotonde St. Honoré',
#        'location': {'lat': 48.86458252806462,
#         'lng': 2.3327020437479082,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86458252806462,
#           'lng': 2.3327020437479082}],
#         'distance': 236,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5953f0feeacf45405b8137bf-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53b65301498e8cb57224f80c',
#        'name': 'Hôtel Ritz Paris',
#        'location': {'address': '15 place Vendôme',
#         'lat': 48.8680513241284,
#         'lng': 2.3285874913737796,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.8680513241284,
#           'lng': 2.3285874913737796}],
#         'distance': 380,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['15 place Vendôme', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53b65301498e8cb57224f80c-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9b68d273df8cfafe71f6ec',
#        'name': 'Le Petit Colbert',
#        'location': {'address': '8 rue Monsigny',
#         'lat': 48.86871940772763,
#         'lng': 2.335391898128121,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86871940772763,
#           'lng': 2.335391898128121}],
#         'distance': 273,
#         'postalCode': '75002',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['8 rue Monsigny', '75002 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d9b68d273df8cfafe71f6ec-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4b65e2f964a5201c9a26e3',
#        'name': 'Hôtel Westminster',
#        'location': {'address': '13 rue de la Paix',
#         'lat': 48.86940842794544,
#         'lng': 2.331189349027926,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86940842794544,
#           'lng': 2.331189349027926}],
#         'distance': 343,
#         'postalCode': '75002',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['13 rue de la Paix', '75002 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '53783053'}},
#       'referralId': 'e-0-4b4b65e2f964a5201c9a26e3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda13f964a520e63621e3',
#        'name': 'Le Grand Véfour',
#        'location': {'address': '17 rue de Beaujolais',
#         'lat': 48.865986232957,
#         'lng': 2.337898549928304,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.865986232957,
#           'lng': 2.337898549928304}],
#         'distance': 342,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['17 rue de Beaujolais', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda13f964a520e63621e3-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d878fb87d552d43abc0d0eb',
#        'name': 'Hôtel Molière',
#        'location': {'address': '21, rue Moliere',
#         'lat': 48.86546909587968,
#         'lng': 2.3362403879499856,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86546909587968,
#           'lng': 2.3362403879499856}],
#         'distance': 251,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['21, rue Moliere', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '42945174'}},
#       'referralId': 'e-0-4d878fb87d552d43abc0d0eb-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5318c03b498e5ea5cf57b72d',
#        'name': 'Anticafé Louvre',
#        'location': {'address': '10 rue de Richelieu',
#         'lat': 48.864258692486615,
#         'lng': 2.3361090136701703,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.864258692486615,
#           'lng': 2.3361090136701703}],
#         'distance': 336,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['10 rue de Richelieu', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5318c03b498e5ea5cf57b72d-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56252625498e5a75588fffda',
#        'name': 'Pho 14 Opera',
#        'location': {'address': 'Rue Molière 17',
#         'lat': 48.8653,
#         'lng': 2.33601,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.8653,
#           'lng': 2.33601}],
#         'distance': 248,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris 01 Louvre',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['Rue Molière 17',
#          '75001 Paris-1ER-Arrondissement',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'shortName': 'Vietnamese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '506963593'}},
#       'referralId': 'e-0-56252625498e5a75588fffda-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b39f154f964a520b25f25e3',
#        'name': 'Workshop Issé',
#        'location': {'address': '11 rue Saint-Augustin',
#         'lat': 48.8688947285211,
#         'lng': 2.33706581214639,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.8688947285211,
#           'lng': 2.33706581214639}],
#         'distance': 369,
#         'postalCode': '75002',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['11 rue Saint-Augustin',
#          '75002 Paris',
#          'France']},
#        'categories': [{'id': '4bf58dd8d48988d1f5941735',
#          'name': 'Gourmet Shop',
#          'pluralName': 'Gourmet Shops',
#          'shortName': 'Gourmet',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b39f154f964a520b25f25e3-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c5871aa6201e21e311c8070',
#        'name': 'Le Cap Bourbon',
#        'location': {'address': '1 rue Louis Le Grand',
#         'lat': 48.86803482270562,
#         'lng': 2.33172904453959,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86803482270562,
#           'lng': 2.33172904453959}],
#         'distance': 192,
#         'postalCode': '75002',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['1 rue Louis Le Grand', '75002 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c5871aa6201e21e311c8070-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0bc880f964a5209c3323e3',
#        'name': 'Drouant',
#        'location': {'address': '16-18 place Gaillon',
#         'lat': 48.86887611183509,
#         'lng': 2.3343905564704133,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86887611183509,
#           'lng': 2.3343905564704133}],
#         'distance': 257,
#         'postalCode': '75002',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['16-18 place Gaillon', '75002 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '89412086'}},
#       'referralId': 'e-0-4b0bc880f964a5209c3323e3-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8b7bb1e51e6dcbf58a72de',
#        'name': 'La Cure Gourmande',
#        'location': {'address': "49 Avenue de l'Opéra",
#         'lat': 48.86994387364028,
#         'lng': 2.332642981875698,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86994387364028,
#           'lng': 2.332642981875698}],
#         'distance': 368,
#         'postalCode': '75002',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ["49 Avenue de l'Opéra", '75002 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d117951735',
#          'name': 'Candy Store',
#          'pluralName': 'Candy Stores',
#          'shortName': 'Candy Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8b7bb1e51e6dcbf58a72de-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b94defef964a520ef8534e3',
#        'name': 'Goyard',
#        'location': {'address': '233 rue Saint Honoré',
#         'lat': 48.86647624483724,
#         'lng': 2.328925407729518,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 48.86647624483724,
#           'lng': 2.328925407729518}],
#         'distance': 323,
#         'postalCode': '75001',
#         'cc': 'FR',
#         'city': 'Paris',
#         'state': 'Île-de-France',
#         'country': 'France',
#         'formattedAddress': ['233 rue Saint Honoré', '75001 Paris', 'France']},
#        'categories': [{'id': '4bf58dd8d48988d102951735',
#          'name': 'Accessories Store',
#          'pluralName': 'Accessories Stores',
#          'shortName': 'Accessories',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_accessories_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b94defef964a520ef8534e3-99'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                         name   categories        lat       lng
# 0               Pierre Hermé  Pastry Shop  48.868222  2.333397
# 1  Le Roch Hotel & Spa Paris        Hotel  48.866200  2.332995
# 2         Cantine California   Food Truck  48.867401  2.332017
# 3            Boulangerie Aki       Bakery  48.866211  2.335458
# 4           Brasserie Réjane   Restaurant  48.865486  2.334824

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 100 venues were returned by Foursquare.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ### Now write the code to run the above function on each cities and create a new dataframe called france_venues.

# %%
france_venues = getNearbyVenues(names=data_df['CITY'],
                                   latitudes=data_df['LATITUDE'],
                                   longitudes=data_df['LONGITUDE']
                                  )
# Out:
# Paris
# Lyon
# Marseille
# Lille
# Nice
# Toulouse
# Bordeaux
# Rouen
# Strasbourg
# Nantes
# Metz
# Grenoble
# Toulon
# Montpellier
# Nancy
# Saint-Étienne
# Melun
# Le Havre
# Tours
# Clermont-Ferrand
# Orléans
# Mulhouse
# Rennes
# Reims
# Caen
# Angers
# Dijon
# Nîmes

# %% [markdown]
# #### Let's check the size of the resulting dataframe

# %%
print(france_venues.shape)
france_venues.head()

# %%
df_venues2 = france_venues.copy()
df_venues3 = france_venues.copy()
df_venues_rest = df_venues2[df_venues2['Venue Category'].str.contains('Bar')].reset_index(drop=True)
df_venues_rest['Venue Type'] = 'Bar'
df_venues_hotel = df_venues3[df_venues3['Venue Category'].str.contains('Plaza')].reset_index(drop=True)
df_venues_hotel['Venue Type'] = 'Plaza'
df_venues_final = pd.concat([df_venues_rest,df_venues_hotel]).reset_index(drop=True)
df_venues_final.shape

# %%
df_venues_final.groupby('Neighborhood')['Venue Type']\
.value_counts()\
.unstack(level=1)\
.plot.bar(stacked=True)

# %%
print('There are {} uniques categories.'.format(len(france_venues['Venue Category'].unique())))

# %% [markdown]
# ### Analyze Each Cities

# %%
# one hot encoding
france_onehot = pd.get_dummies(france_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
france_onehot['Neighborhood'] =  france_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [france_onehot.columns[-1]] + list(france_onehot.columns[:-1])
france_onehot = france_onehot[fixed_columns]

france_onehot.head()

# %% [markdown]
# ### Next, let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
france_grouped = france_onehot.groupby('Neighborhood').mean().reset_index()
france_grouped

# %% [markdown]
# #### Let's print each cities along with the top 5 most common venues

# %%
num_top_venues = 5

for hood in france_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = france_grouped[france_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Now let's create the new dataframe and display the top 10 venues for each cities.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = france_grouped['Neighborhood']

for ind in np.arange(france_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(france_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted

# %% [markdown]
# ## Cluster Neighborhoods

# %% [markdown]
# Run k-means to cluster the neighborhood into 5 clusters.

# %%
# set number of clusters
kclusters = 5

france_grouped_clustering = france_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(france_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]

# %% [markdown]
# Let's create a new dataframe that includes the cluster as well as the top 10 venues for each cities.

# %%
france_merged = data_df

# add clustering labels
france_merged['Cluster Labels'] = kmeans.labels_

# merge toronto_grouped with france to add latitude/longitude for each neighborhood
france_merged = france_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='CITY')

france_merged.head() # check the last columns!

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=6)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(france_merged['LATITUDE'], france_merged['LONGITUDE'], france_merged['CITY'], france_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters

# %%
france_merged.count()

# %% [markdown]
# ### CLUSTER 1

# %%
cluster1 = france_merged.loc[france_merged['Cluster Labels'] == 0, france_merged.columns[[0] + list(range(4, france_merged.shape[1]))]]
cluster1

# %% [markdown]
# ### CLUSTER 2

# %%
france_merged.loc[france_merged['Cluster Labels'] == 1, france_merged.columns[[0] + list(range(4, france_merged.shape[1]))]]

# %% [markdown]
# ### CLUSTER 3

# %%
france_merged.loc[france_merged['Cluster Labels'] == 2, france_merged.columns[[0] + list(range(6, france_merged.shape[1]))]]

# %% [markdown]
# ### CLUSTER 4

# %%
france_merged.loc[france_merged['Cluster Labels'] == 3, france_merged.columns[[0] + list(range(6, france_merged.shape[1]))]]

# %% [markdown]
# ### CLUSTER 5

# %%
france_merged.loc[france_merged['Cluster Labels'] == 4, france_merged.columns[[0] + list(range(6, france_merged.shape[1]))]]

# %%
get_Hotel = france_merged[france_merged.eq('Hotel').any(axis=1)]  
tot_cluster = get_Hotel[france_merged.eq('Bar','Plaza','Shopping Mall').any(axis=1)]  
#tot_cluster = get_cluster[get_cluster.eq('Plaza').any(axis=1)]
tot_cluster.head(10)

# %% [markdown]
# ### USER_CLUSTER 1

# %% [markdown]
# Cluster based on user selection

# %%
tot_cluster.loc[tot_cluster['Cluster Labels'] == 0, tot_cluster.columns[[0] + list(range(6, france_merged.shape[1]))]]

# %% [markdown]
# ### USER_CLUSTER 2

# %% [markdown]
# Cluster based on user selection

# %%
tot_cluster.loc[tot_cluster['Cluster Labels'] == 1, tot_cluster.columns[[0] + list(range(6, france_merged.shape[1]))]]

# %% [markdown]
# ### USER_CLUSTER 3

# %% [markdown]
# Cluster based on user selection

# %%
tot_cluster.loc[tot_cluster['Cluster Labels'] == 2, tot_cluster.columns[[0] + list(range(6, france_merged.shape[1]))]]

# %% [markdown]
# ### USER_CLUSTER 4

# %% [markdown]
# Cluster based on user selection

# %%
tot_cluster.loc[tot_cluster['Cluster Labels'] == 3, tot_cluster.columns[[0] + list(range(6, france_merged.shape[1]))]]

# %% [markdown]
# ### USER_CLUSTER 5

# %% [markdown]
# Cluster based on user selection

# %%
tot_cluster.loc[tot_cluster['Cluster Labels'] == 4, tot_cluster.columns[[0] + list(range(6, france_merged.shape[1]))]]

# %% [markdown]
# ## Create MAP for USER based on user input filter

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=5)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(tot_cluster['LATITUDE'], tot_cluster['LONGITUDE'], tot_cluster['CITY'], tot_cluster['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters

# %% [markdown]
# 5.)Discussion :
#
# 	It is interesting how the venues and people from different cities varies to one another. The main differentiation is after the clusters filtered upon the user inputs but also we could see some common venues among the clusters.
#
# As a recommendation, it must be said in study to make better predictions about the where to locate cluster city with user venue. for example if tourist want to locate the city with hotel clusters based on bar,plaza,gym etc..
#
#
# 6.)Conclusion :
#
# 	As far as we can see with this data, some of the clusters are not populated because of user filter.
#
# It is highly possible that user_cluster 1 & 5 has more cities which has the user preferences of hotel cluster. If the user input data should perform with more data and logic also framed in proper way then we can provide more accurate output .
#
# 7.)References
#
# https://developer.foursquare.com/docs/api/venues/
#
# https://simplemaps.com/data/fr-cities
#
# https://www.coursera.org/
